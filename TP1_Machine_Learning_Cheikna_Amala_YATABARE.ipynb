# %% [markdown]
# <div  style="border-radius: 10px; border: 2px solid #3498db; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.2);">
#     <h1 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); font-weight: bold; margin-bottom: 10px;">📊TP1: Machine Learning
# </div>

# %% [markdown]
# <div  style="border-radius: 10px; border: 2px solid #3498db; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 2px 4px rgba(0, 0, 0, 0.2);">
#     <h1 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5); font-weight: bold; margin-bottom: 10px;"><li> &#128587; Cheikna Amala YATABARE</li></h1>
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div style="border-radius: 10px; border: 2px solid #FFD700; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.1); text-align: left;">
#         <h3 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); font-size: 24px; font-weight: bold; margin-bottom: 10px;">
#             <span style="color: red ;"> </span> Chargement des packages
#         </h3>
#         <p style="font-size: 18px; color: #333;">
# </html>
# .
#         </p>
#     </div>
# </body>
# </html>
#
# </html>

# %%
#!pip install ydata-profiling==4.6.1

# %%
import seaborn as sns
from pathlib import Path
import matplotlib.pyplot as plt
import missingno as msno
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.graph_objs as go
from plotly.subplots import make_subplots
from ydata_profiling import ProfileReport
from yellowbrick.regressor import ResidualsPlot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from typing import Tuple, Dict, List

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div style="border-radius: 10px; border: 2px solid #FFD700; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.1); text-align: left;">
#         <h3 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); font-size: 24px; font-weight: bold; margin-bottom: 10px;">
#             <span style="color: red ;"> </span> Base de donnée
#         </h3>
#         <p style="font-size: 18px; color: #333;">
# </html>
# .
#         </p>
#     </div>
# </body>
# </html>
#
# </html>

# %%
# Return a new path pointing to the current working directory
HOME_DIR = Path.cwd().parent

# create a variable for data directory
DATA_DIR = Path(HOME_DIR, "data")

print(f"Work directory: {HOME_DIR} \nData directory: {DATA_DIR}")
# Out:
# Work directory: C:\Users\user\OneDrive
# Data directory: C:\Users\user\OneDrive\data

# %%
# you must put the CSV file billets.csv in data directory, cf above cell
data = pd.read_csv( "C:/Users/user/OneDrive/ML/data/billets.csv", sep=";")
data.shape  # data frame dimensions (nb rows, nb columns)
# Out:
# (1500, 7)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div style="border-radius: 10px; border: 2px solid #FFD700; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.1); text-align: left;">
#         <h3 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); font-size: 24px; font-weight: bold; margin-bottom: 10px;">
#             <span style="color: red ;"> 1.1</span> Statistiques descriptives
#         </h3>
#         <p style="font-size: 18px; color: #333;">
# </html>
# .
#         </p>
#     </div>
# </body>

# %%
data.head()
# Out:
#    is_genuine  diagonal  height_left  height_right  margin_low  margin_up  \
# 0        True    171.81       104.86        104.95        4.52       2.89
# 1        True    171.46       103.36        103.66        3.77       2.99
# 2        True    172.69       104.48        103.50        4.40       2.94
# 3        True    171.36       103.91        103.94        3.62       3.01
# 4        True    171.73       104.28        103.46        4.04       3.48
#
#    length
# 0  112.83
# 1  113.09
# 2  113.16
# 3  113.51
# 4  112.54

# %%
data.describe(include="all")
# Out:
#        is_genuine     diagonal  height_left  height_right   margin_low  \
# count        1500  1500.000000  1500.000000   1500.000000  1463.000000
# unique          2          NaN          NaN           NaN          NaN
# top          True          NaN          NaN           NaN          NaN
# freq         1000          NaN          NaN           NaN          NaN
# mean          NaN   171.958440   104.029533    103.920307     4.485967
# std           NaN     0.305195     0.299462      0.325627     0.663813
# min           NaN   171.040000   103.140000    102.820000     2.980000
# 25%           NaN   171.750000   103.820000    103.710000     4.015000
# 50%           NaN   171.960000   104.040000    103.920000     4.310000
# 75%           NaN   172.170000   104.230000    104.150000     4.870000
# max           NaN   173.010000   104.880000    104.950000     6.900000
#
#           margin_up      length
# count   1500.000000  1500.00000
# unique          NaN         NaN
# ...

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 4))

sns.histplot(data["margin_low"], color='r', kde=True, ax=axes[0])
axes[0].set_title('Distribution - Margin low')

sns.histplot(np.log(data["margin_low"]), color='b', kde=True, ax=axes[1])
axes[1].set_title('Distribution - Margin low $log$')
axes[1].set_xscale('log');

# %%
sns.pairplot(data, hue="is_genuine", palette="Paired", corner=True, diag_kind="kde");

# %%
data.select_dtypes(include=[int, float]).corr(method="pearson")
# Out:
#               diagonal  height_left  height_right  margin_low  margin_up  \
# diagonal      1.000000     0.019472     -0.024492   -0.111534  -0.055649
# height_left   0.019472     1.000000      0.242279    0.302643   0.246522
# height_right -0.024492     0.242279      1.000000    0.391085   0.307005
# margin_low   -0.111534     0.302643      0.391085    1.000000   0.431606
# margin_up    -0.055649     0.246522      0.307005    0.431606   1.000000
# length        0.097587    -0.320863     -0.401751   -0.666753  -0.520575
#
#                 length
# diagonal      0.097587
# height_left  -0.320863
# height_right -0.401751
# margin_low   -0.666753
# margin_up    -0.520575
# length        1.000000

# %%
# correlation plot
plt.figure(figsize=(10, 7))
corr = data.select_dtypes(include=[int, float]).corr(method="pearson")
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr, cmap='Greens', annot=True, square=True,
            fmt='.3f',
            mask=mask,
            cbar=True, vmin=-1, vmax=1);

# %%
from sklearn import linear_model
import statsmodels.formula.api as smf
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from statsmodels.stats.diagnostic import het_white , normal_ad

# %%
data_model = data.loc[lambda dfr: dfr.margin_low.notnull()]
data_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1463 entries, 0 to 1499
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   is_genuine    1463 non-null   bool
#  1   diagonal      1463 non-null   float64
#  2   height_left   1463 non-null   float64
#  3   height_right  1463 non-null   float64
#  4   margin_low    1463 non-null   float64
#  5   margin_up     1463 non-null   float64
#  6   length        1463 non-null   float64
# dtypes: bool(1), float64(6)
# memory usage: 81.4 KB

# %%
# Création des variables explicatives et cible:
# X est la liste des variables explicatives et y est la variable cible
X = data_model.loc[:, ["diagonal", "height_left", "height_right", "margin_up", "length"]]  # ou data.drop(["margin_low", "is_genuine"], axis=1)
y = data_model.loc[:, 'margin_low']

# %% [markdown]
# ## Train/ Test split

# %%
# Séparons nos données en un jeu d'entraînement et un jeu de test :
# 30% des données dans le jeu de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"Train set - X: {X_train.shape} ; y: {y_train.shape} \nTest set - X: {X_test.shape} ; y: {y_test.shape}")
# Out:
# Train set - X: (1024, 6) ; y: (1024,)
# Test set - X: (439, 6) ; y: (439,)

# %% [markdown]
# ## Definition d'une fonction d'entrainement

# %% [markdown]
# ## Standardisation

# %%
# Standardisons les données :
std_scaler = StandardScaler().fit(X_train)  # Standardize features by removing the mean and scaling to unit variance.
X_train_std = std_scaler.transform(X_train)
X_test_std = std_scaler.transform(X_test)

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div style="border-radius: 10px; border: 2px solid #FFD700; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.1); text-align: left;">
#         <h3 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); font-size: 24px; font-weight: bold; margin-bottom: 10px;">
#             <span style="color: red ;"> 1.</span> Exercice 1
#         </h3>
#         <p style="font-size: 18px; color: #333;">Cette section est consacrée à l'analyse des variables explicatives. Et de faire une comparaison entre le jeu de train et le jeu de test
# </b
# </html>
# .
#         </p>
#     </div>
# </body>
# </html>
#
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div style="border-radius: 10px; border: 2px solid #FFD700; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.1); text-align: left;">
#         <h3 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); font-size: 24px; font-weight: bold; margin-bottom: 10px;">
#             <span style="color: red ;"> 1.1</span> Explication des variables explicatives du modele Elastic Net
#         </h3>
#         <p style="font-size: 18px; color: #333;">Cette section est consacrée à l'analyse des variables explicatives. Et de faire une comparaison entre le jeu de train et le jeu de test
# </b
# </html>
# .
#         </p>
#     </div>
# </body>
# </html>
#
# </html>

# %% [markdown]
# ## Elastic Net

# %%
elastic_net = linear_model.ElasticNet(alpha=1.0, l1_ratio=0.5)  
elastic_net.fit(X_train, y_train)

y_pred = elastic_net.predict(X_test)

mse = metrics.mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
mae = metrics.mean_absolute_error(y_test, y_pred)

evaluation_results = pd.DataFrame({
    'Modèle': [ 'ElasticNet'],
    'MSE': [mse],
    'RMSE': [rmse],
    'MAE': [mae]
})

# Afficher les résultats
print(evaluation_results)
# Out:
#        Modèle      MSE      RMSE       MAE
# 0  ElasticNet  0.42698  0.653437  0.524162

# %% [markdown]
# ## Visalisation des resultats des variables explicatives

# %%
# Coefficients des variables explicatives
coefficients = elastic_net.coef_

coefficients_df = pd.DataFrame({
    'Variable': X_train.columns,
    'Coefficient': coefficients
})

# Afficher les coefficients des variables explicatives
print("\nCoefficients des variables explicatives :")
print(coefficients_df)
# Out:
# Coefficients des variables explicatives :
#        Variable  Coefficient
# 0    is_genuine         -0.0
# 1      diagonal         -0.0
# 2   height_left          0.0
# 3  height_right          0.0
# 4     margin_up          0.0
# 5        length         -0.0

# %% [markdown]
# ## Analyse des Resulats des varaibles explicatives

# %% [markdown]
# # Interprétation des Résultats du Modèle Elastic Net
#
# ## Évaluation des Erreurs du Modèle Elastic Net
#
# Le modèle Elastic Net présente une **Mean Squared Error (MSE)** de 0.42698, une **Root Mean Squared Error (RMSE)** de 0.653437, et une **Mean Absolute Error (MAE)** de 0.524162. Ces indicateurs montrent que l'erreur moyenne quadratique et absolue des prédictions est relativement modeste. La RMSE, qui est l'erreur quadratique moyenne élevée au carré, permet d'évaluer la précision globale des prédictions en prenant en compte l'influence des erreurs plus importantes.
#
# ## Interprétation des Coefficients des Variables
#
# Les coefficients associés aux variables explicatives (`is_genuine`, `diagonal`, `height_left`, `height_right`, `margin_up`, `length`) sont tous égaux à zéro :
#
# | Variable        | Coefficient |
# |-----------------|------------|
# | is_genuine      | 0.0        |
# | diagonal        | 0.0        |
# | height_left     | 0.0        |
# | height_right    | 0.0        |
# | margin_up       | 0.0        |
# | length          | 0.0        |
#
# Cela signifie qu'aucune de ces variables n'exerce une influence significative sur la prédiction du modèle Elastic Net après régularisation. En Elastic Net, les coefficients peuvent être réduits à zéro, combinant la sélection de variables (comme dans le Lasso) et le contrôle de la complexité du modèle (comme dans le Ridge), ce qui indique ici que le modèle considère ces variables comme non pertinentes pour la prédiction.
#
# ## Conclusion
#
# En somme, le modèle Elastic Net n'utilise aucune des variables explicatives pour prédire la variable cible, probablement en raison de la régularisation qui annule leur contribution. Cela peut signifier que les données contiennent peu de signal prédictif pour la cible, ou que la régularisation est trop forte, supprimant ainsi l’influence des variables. Une évaluation des paramètres de régularisation ou une exploration de nouvelles variables pourrait améliorer les prédictions du modèle.

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div style="border-radius: 10px; border: 2px solid #FFD700; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.1); text-align: left;">
#         <h3 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); font-size: 24px; font-weight: bold; margin-bottom: 10px;">
#             <span style="color: red ;"> 1.1</span> Afficher les differences entre le jeu de test et le jeu de train
#         </h3>
#         <p style="font-size: 18px; color: #333;">
# </body>
# </html>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ks_2samp

def analyze_train_test_split(X_train, X_test):
    """
    Fonction pour analyser la répartition entre les données d'entraînement et de test.
    Comprend la comparaison des distributions, l'analyse statistique, les matrices de corrélation,
    le test de Kolmogorov-Smirnov, et le calcul des différences relatives.
    """

    # 1. Comparaison des distributions
    print("\n--- Comparaison des distributions des variables ---\n")
    for column in X_train.columns:
        fig, axs = plt.subplots(1, 2, figsize=(14, 6))
        
        # Graphique de distribution
        sns.kdeplot(X_train[column], label="Train", color="blue", fill=True, ax=axs[0])
        sns.kdeplot(X_test[column], label="Test", color="red", fill=True, ax=axs[0])
        axs[0].set_title(f'Distribution de {column}')
        axs[0].legend()

        # Box plot
        data_to_plot = pd.DataFrame({'Train': X_train[column], 'Test': X_test[column]})
        sns.boxplot(data=data_to_plot, ax=axs[1])
        axs[1].set_title(f'Boxplot de {column}')
        axs[1].set_xticklabels(['Train', 'Test'])
        
        plt.tight_layout()
        plt.show()

    # 2. Analyse statistique descriptive
    print("\n--- Comparaison statistique descriptive ---\n")
    stats_comparison = pd.DataFrame({
        'Train_Mean': X_train.mean(),
        'Test_Mean': X_test.mean(),
        'Train_Std': X_train.std(),
        'Test_Std': X_test.std(),
        'Train_Min': X_train.min(),
        'Test_Min': X_test.min(),
        'Train_Max': X_train.max(),
        'Test_Max': X_test.max()
    })
    print(stats_comparison)

    # 3. Matrices de corrélation
    print("\n--- Matrices de corrélation ---\n")
    fig, axs = plt.subplots(1, 2, figsize=(16, 6))
    
    sns.heatmap(X_train.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1, ax=axs[0])
    axs[0].set_title('Corrélations - Train')
    
    sns.heatmap(X_test.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1, ax=axs[1])
    axs[1].set_title('Corrélations - Test')
    
    plt.tight_layout()
    plt.show()

    # 4. Test de Kolmogorov-Smirnov
    print("\n--- Résultats du test de Kolmogorov-Smirnov ---\n")
    ks_results = {}
    for column in X_train.columns:
        statistic, p_value = ks_2samp(X_train[column], X_test[column])
        ks_results[column] = {
            'KS_Statistic': statistic,
            'P_Value': p_value,
            'Distributions_Similaires': p_value > 0.05
        }
    ks_df = pd.DataFrame(ks_results).T
    print(ks_df)

    # 5. Calcul des différences relatives
    print("\n--- Différences relatives (%) entre Test et Train ---\n")
    rel_diff = pd.DataFrame({
        'Diff_Moyenne_%': ((X_test.mean() - X_train.mean()) / X_train.mean() * 100),
        'Diff_Std_%': ((X_test.std() - X_train.std()) / X_train.std() * 100)
    })
    print(rel_diff)

    return stats_comparison, ks_df, rel_diff

# %% [markdown]
# ## resultats des différences

# %%
analyze_train_test_split (X_train, X_test)
# Out:
# --- Comparaison des distributions des variables ---
# --- Comparaison statistique descriptive ---
#
#               Train_Mean   Test_Mean  Train_Std  Test_Std Train_Min Test_Min  \
# is_genuine      0.664062    0.662870   0.472548  0.473269     False    False
# diagonal      171.962383  171.951754   0.301231  0.315320    171.05   171.04
# height_left   104.035996  104.020456   0.300359  0.297897    103.22   103.14
# height_right  103.921045  103.922483   0.326683  0.318636    102.91   103.03
# margin_up       3.157305    3.143235   0.230871  0.232813      2.56     2.27
# length        112.675596  112.672802   0.873045  0.874626    109.97   109.49
#
#              Train_Max Test_Max
# is_genuine        True     True
# diagonal        172.89   173.01
# height_left     104.88   104.83
# height_right    104.95   104.95
# margin_up         3.91     3.77
# length          114.32   114.13
#
# --- Matrices de corrélation ---
# --- Résultats du test de Kolmogorov-Smirnov ---
#
# ...

# %% [markdown]
# # Analyse des résultats
#
# ### Résultats du Test de Kolmogorov-Smirnov et Similarité des Distributions
#
# Les résultats du test de Kolmogorov-Smirnov montrent une forte similarité des distributions entre les ensembles de test et d'entraînement pour toutes les variables. Chaque variable présente un faible `KS_Statistic` et une `P_Value` élevée, suggérant que les différences entre les deux ensembles ne sont pas statistiquement significatives. Cette uniformité dans les distributions indique que les données de test et d'entraînement sont bien représentées de manière similaire, ce qui est essentiel pour assurer la validité des évaluations et des prédictions de modèles d’apprentissage automatique.
#
# ### Analyse des Différences Relatives entre Moyennes et Écarts Types
#
# Les analyses de différences relatives entre moyennes et écarts types montrent également des écarts minimes pour chaque variable, avec des valeurs très proches entre les deux ensembles de données. Par exemple, la variable `diagonal` a une différence de moyenne très faible, tout comme les autres variables telles que `height_left` et `height_right`, qui affichent également une faible variation. De même, les valeurs maximales et minimales des variables sont proches, ce qui confirme l’homogénéité des bornes et assure la représentativité des cas dans l’ensemble de test par rapport à l’entraînement.
#
# ### Conclusion sur la Cohérence et la Représentativité des Données
#
# En somme, les tests de similarité des distributions et les faibles écarts dans les moyennes et les dispersions confirment que les ensembles de test et d’entraînement sont comparables et de bonne qualité pour l’évaluation des modèles. Cette cohérence est cruciale pour éviter les biais de généralisation et garantir des performances prédictives fiables. Ces résultats suggèrent que les données sont bien équilibrées pour des modèles robustes, permettant une évaluation précise et stable entre les deux ensembles.

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div style="border-radius: 10px; border: 2px solid #FFD700; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.1); text-align: left;">
#         <h3 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); font-size: 24px; font-weight: bold; margin-bottom: 10px;">
#             <span style="color: red ;"> </span> Exercice 2
#         </h3>
#         <p style="font-size: 18px; color: #333;">Cette section est consacrée à optimiser les modèles Ridge et Lasso, Générer la feature importante de chacun des deux modèles et enfin à Analyser les résultats</p>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div style="border-radius: 10px; border: 2px solid #FFD700; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.1); text-align: left;">
#         <h3 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); font-size: 24px; font-weight: bold; margin-bottom: 10px;">
#             <span style="color: red ;"> 1.</span> Optimisation des modèles Ridge et Lasso
#         </h3>
#         <p style="font-size: 18px; color: #333;"></p>
# </html>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div style="border-radius: 10px; border: 2px solid #FFD700; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.1); text-align: left;">
#         <h3 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); font-size: 24px; font-weight: bold; margin-bottom: 10px;">
#             <span style="color: red ;"> 1.1</span> Ridge
#         </h3>
#         <p style="font-size: 18px; color: #333;"></p>
# </html>

# %% [markdown]
# ## 1.1.1 Optimisation de la régression Lasso avec un pipeline et GridSearchCV

# %% [markdown]
# ## Nous allons dans une première étape choisir alpha entre 0.001 et 100

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Ridge, Lasso
from sklearn.pipeline import Pipeline
import pandas as pd
import matplotlib.pyplot as plt


# Créer le pipeline Ridge
reg_ridge_pipe = Pipeline(steps=[
    ("scaler", MinMaxScaler()),
    ("regressor", Ridge())
])

# Définir la grille des hyperparamètres pour Ridge
param_grid_ridge = {
    "regressor__alpha": [0.001, 0.01, 0.1, 1, 10, 100],
    "regressor__fit_intercept": [True, False]
}

# Créer l'objet GridSearchCV pour Ridge
grid_search_ridge = GridSearchCV(reg_ridge_pipe, param_grid_ridge, cv=10, scoring="r2", return_train_score=True)

# Effectuer la recherche sur la grille pour Ridge
grid_search_ridge.fit(X_train, y_train)

# Afficher les meilleurs paramètres pour Ridge
print("Meilleurs paramètres pour Ridge:", grid_search_ridge.best_params_)
print("Meilleur score R2 pour Ridge:", grid_search_ridge.best_score_)
# Out:
# Meilleurs paramètres pour Ridge: {'regressor__alpha': 1, 'regressor__fit_intercept': True}
# Meilleur score R2 pour Ridge: 0.45725848363021493

# %% [markdown]
# ### Nous obtenons ainsi pour une première optimisation la valeur de alpha égal à 1 sur une plage allant de 0.001 à 100. Et un score de 0.4572

# %% [markdown]
# ## 1.1.2 Régression Ridge avec Cross-validation et GridSearchCV

# %%
# Diviser les données en jeu d'entraînement et de test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Définir la grille des hyperparamètres pour Ridge
param_grid_ridge = {
    "alpha": np.logspace(-3, 3, 50),  # Plage de valeurs pour alpha
}

# Créer un modèle Ridge
ridge = Ridge(max_iter=10000)

# Créer l'objet GridSearchCV pour Ridge avec validation croisée (cv=10)
grid_search_ridge = GridSearchCV(ridge, param_grid_ridge, cv=10, scoring="r2", return_train_score=True)

# Effectuer la recherche sur la grille pour Ridge
grid_search_ridge.fit(X_train, y_train)

# Meilleure valeur de alpha pour Ridge
best_alpha_ridge = grid_search_ridge.best_params_['alpha']
best_r2_ridge = grid_search_ridge.best_score_

# Afficher les meilleurs paramètres et le meilleur score R²
print(f"Meilleure valeur de alpha pour Ridge : {best_alpha_ridge}")
print(f"Meilleur score R² pour Ridge : {best_r2_ridge}")

# Tracer les résultats pour Ridge (relation entre alpha et le score R²)
plt.figure(figsize=(10, 6))
plt.plot(grid_search_ridge.cv_results_['param_alpha'], grid_search_ridge.cv_results_['mean_test_score'], marker='o', linestyle='-', color='b', label='R² moyen (Ridge)')
plt.xscale('log')
plt.xlabel("Valeur de alpha")
plt.ylabel("R² moyen")
plt.title("Impact de alpha sur la performance du modèle Ridge")
plt.axvline(best_alpha_ridge, color='r', linestyle='--', label=f'Alpha optimal: {best_alpha_ridge:.3f}')
plt.legend()
plt.show()
# Out:
# Meilleure valeur de alpha pour Ridge : 8.286427728546842
# Meilleur score R² pour Ridge : 0.4574194992223923

# %% [markdown]
# ### On obtient une valeur de alpha égal à 8.2864 et un R2 qui donne 0.4574 encore plus meilleure que le premier qui consistait à definir des valeurs pour alpha.

# %% [markdown]
# ## Generer des features pour la regression Ridge

# %%
# Afficher les coefficients triés par importance
best_ridge_model = grid_search_ridge.best_estimator_
ridge_coef = pd.Series(best_ridge_model.coef_, index=X_train.columns)
ridge_coef_sorted = ridge_coef.abs().sort_values(ascending=False)

print("\nCoefficients triés par importance (Ridge) :")
print(ridge_coef_sorted.head(10))
# Out:
# Coefficients triés par importance (Ridge) :
# length          0.408780
# margin_up       0.251003
# height_right    0.247234
# height_left     0.169039
# diagonal        0.081523
# dtype: float64

# %%
# Affichage des résultats de la recherche croisée pour Ridge
cv_results_ridge = pd.DataFrame(grid_search_ridge.cv_results_)
cv_results_ridge.head(10)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_alpha  \
# 0       0.006399      0.003200         0.002400        0.003667       0.001
# 1       0.004800      0.003919         0.000800        0.002400    0.001326
# 2       0.001599      0.003197         0.002401        0.003668    0.001758
# 3       0.000800      0.002400         0.003201        0.003921     0.00233
# 4       0.001602      0.003203         0.000798        0.002395    0.003089
# 5       0.002398      0.003664         0.000802        0.002405    0.004095
# 6       0.001599      0.003199         0.001600        0.003200    0.005429
# 7       0.000800      0.002399         0.001598        0.003197    0.007197
# 8       0.000798      0.002395         0.002401        0.003668    0.009541
# 9       0.002397      0.003662         0.003200        0.003920    0.012649
#
#                              params  split0_test_score  split1_test_score  \
# ...

# %% [markdown]
# ## Importance des variables

# %%
# Obtenez les prédictions sur l'ensemble de test
y_pred_ridge = grid_search_ridge.best_estimator_.predict(X_test)

# Afficher les premières prédictions
print("Prédictions pour Ridge sur X_test :")
print(y_pred_ridge)
# Out:
# Prédictions pour Ridge sur X_test :
# [4.96598366 4.2960526  4.37239275 4.09092454 4.00441453 4.1060392
#  4.85907032 4.12764708 4.18880257 3.86072614 5.14470272 4.12215523
#  4.45035315 4.08744357 5.9052134  4.10417744 4.12386723 3.98020879
#  4.17762976 5.09301134 4.23688015 4.77411739 5.0209371  4.09517953
#  4.08068548 4.0130897  4.1721333  4.10695448 4.92783774 4.25378839
#  5.09842821 4.15568589 4.49288853 4.19665289 4.00098867 4.18018602
#  3.98605686 5.58646276 5.70612904 4.15115949 4.24943973 4.38891825
#  4.78517656 4.46757495 5.35974321 4.42471292 4.73794459 4.94248822
#  4.26369692 4.72540618 4.27886597 4.20788111 3.95130053 4.11184793
#  4.33873605 4.21216429 4.14477623 4.38383481 4.17685359 5.36886448
#  3.82575197 4.99497049 4.05606579 4.29639032 4.55231001 4.26325477
#  3.90881176 5.26339806 5.23092827 3.98709734 4.91790754 4.37402991
#  5.08743482 4.25295037 4.02167782 4.58770882 4.08072844 4.03782898
# ...

# %% [markdown]
# ## top 30 most important features

# %%
ridge_best = grid_search_ridge.best_estimator_  # Le meilleur modèle trouvé par GridSearchCV
ridge_coef = pd.Series(ridge_best.coef_, index=X_train.columns)

df_feature_importance_ridge = pd.DataFrame({
    'coef': ridge_coef
})
top_30_features_ridge = df_feature_importance_ridge.sort_values("coef", key=lambda v: abs(v), ascending=True).head(30)

top_30_features_ridge.plot(kind="barh", figsize=(10, 7))
plt.title("Top 30 Features les plus importantes (Ridge)", fontsize=14)
plt.axvline(x=0, color='.6', linestyle="--")
plt.subplots_adjust(left=0.3)
plt.show()

# %% [markdown]
# ## Analyse des résultats

# %%
ridge_coef = pd.Series(ridge_best.coef_, index=X_train.columns)
ridge_coef_sorted = lasso_coef.abs().sort_values(ascending=False)
ridge_coef_sorted.plot(kind='bar')
plt.title('Feature Importance - Ridge')
plt.xlabel('Features')
plt.ylabel('Absolute Coefficient Value')
plt.show()

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div style="border-radius: 10px; border: 2px solid #FFD700; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.1); text-align: left;">
#         <h3 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); font-size: 24px; font-weight: bold; margin-bottom: 10px;">
#             <span style="color: red ;"></span> Interpretation du Modèle Ridge
#         </h3>
#         <p style="font-size: 18px; color: #333;">
# </html>

# %% [markdown]
# # Interprétation des Coefficients et Résultats du Modèle Ridge
#
# ## Coefficients du Modèle Ridge
#
# Le modèle Ridge présente des coefficients qui indiquent l'importance relative de chaque variable dans la prédiction. Les coefficients sont les suivants, triés par importance décroissante :
#
# | Variable        | Coefficient |
# |-----------------|------------|
# | length          | 0.408780    |
# | margin_up       | 0.251003    |
# | height_right    | 0.247234    |
# | height_left     | 0.169039    |
# | diagonal        | 0.081523    |
#
# ### Interprétation des Coefficients
#
# 1. **length** a le coefficient le plus élevé (0.408780), indiquant qu'elle a la plus grande influence sur la variable cible. Une variation dans `length` aura donc un impact plus significatif sur la prédiction par rapport aux autres variables.
#
# 2. **margin_up** et **height_right** suivent avec des coefficients respectifs de 0.251003 et 0.247234, montrant qu'elles ont également un impact substantiel, mais légèrement inférieur à celui de `length`.
#
# 3. **height_left** a un coefficient de 0.169039, ce qui indique que son effet est moins marqué mais reste non négligeable par rapport à `diagonal`.
#
# 4. **diagonal** a le coefficient le plus faible (0.081523), ce qui suggère que cette variable a l'impact le plus faible sur la variable cible parmi les variables considérées.
#
#  Meilure Valeur de \(\alpha\) et Meilleur Score \(R^2\)
#
#  **Meilleure valeur de \(\alpha\) pour Ridge :** 8.286427728546842
# - **Meilleur score \(R^2\) pour Ridge :** 0.4574194992223923
#
# ### Interpré on
#
# a valur opimale de \(\alpha\) est \(8.29\), ce qui signifie que c'est le paramètre de régularisation qui minimise l'erreur de prédiction tout en évitant le surapprentissage. Plus cette valeur est élevée, plus la régularisation est forte, ce qui entraîne des coefficients plus proches de zéro.
#
# Le score \(R^2\) de 0.457 indique que le modèle Ridge explique environ 45.7\% de la variance des données. Bien que ce score ne soit pas très élevé, il suggère que le modèle a une capacité raisonnable à prédire la variable cible. Pour améliorer cette performance, on pourrait explorer des transformations de variables, ajuster les paramètres du modèle, ou utiliser d'autres techniques de modélisation.
#
# ## Conclusion
#
# Dans le modèle Ridge, les variables `length`, `margin_up`, et `height_right` sont les plus influentes pour la prédiction de la variable cible, tandis que `diagonal` a une faible importance. La régularisation de \(\alpha = 8.29\) aide à éviter le surapprentissage tout en maintenant une bonne prédiction. Cependant, le score \(R^2\) de 0.457 indique qu'il reste un potentiel d'amélioration dans la modélisation pour mieux capturer la variance des données.
# t aux autres variables.

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div style="border-radius: 10px; border: 2px solid #FFD700; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.1); text-align: left;">
#         <h3 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); font-size: 24px; font-weight: bold; margin-bottom: 10px;">
#             <span style="color: red ;"> 1.2</span>  Lasso
#         </h3>
#         <p style="font-size: 18px; color: #333;"></p>
# </html>

# %% [markdown]
# ## 1.2.1 Optimisation de la régression Lasso avec un pipeline et GridSearchCV
#
# ### Le code utilise un pipeline pour normaliser les données avant de passer au modèle de régression Lasso. `GridSearchCV` optimise les hyperparamètres du modèle pour maximiser la valeur du coefficient de détermination \( R^2 \) avec une validation croisée, puis affiche les coefficients du meilleur modèle, triés en fonction de leur importance.

# %%
# Créer le pipeline Lasso
reg_lasso_pipe = Pipeline(steps=[
    ("scaler", MinMaxScaler()),
    ("regressor", Lasso())
])

# Définir la grille des hyperparamètres pour Lasso
param_grid_lasso = {
    "regressor__alpha":[0.001, 0.01, 0.1, 1, 10, 100] ,
    "regressor__fit_intercept": [True, False]
}

# Créer l'objet GridSearchCV pour Lasso
grid_search_lasso = GridSearchCV(reg_lasso_pipe, param_grid_lasso, cv=10, scoring="r2", return_train_score=True)

# Effectuer la recherche sur la grille pour Lasso
grid_search_lasso.fit(X_train, y_train)

best_lasso_model = grid_search_lasso.best_estimator_.named_steps['regressor']
lasso_coef = pd.Series(best_lasso_model.coef_, index=X_train.columns)
lasso_coef_sorted = lasso_coef.abs().sort_values(ascending=False)

# Afficher les meilleurs paramètres pour Lasso
print("\nMeilleurs paramètres pour Lasso:", grid_search_lasso.best_params_)
print("Meilleur score R2 pour Lasso:", grid_search_lasso.best_score_)
# Out:
# Meilleurs paramètres pour Lasso: {'regressor__alpha': 0.001, 'regressor__fit_intercept': True}
# Meilleur score R2 pour Lasso: 0.45690245395543594

# %% [markdown]
# ## On trouve comme valeur un alpha égal à 0.001 et un score pour le R2 de 0.4569

# %% [markdown]
# ## 1.2.2 Optimisation de la régression Lasso avec validation croisée (cross-validation)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split, cross_val_score
import pandas as pd

# Supposons que X et y soient vos données d'entrée et de sortie
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Définir la gamme des valeurs de alpha
alpha_values = np.logspace(-3, 3, 50)
mean_r2_scores_lasso = []
all_scores = []

# Calculer le score R² moyen pour chaque valeur de alpha
for alpha in alpha_values:
    lasso = Lasso(alpha=alpha, max_iter=10000)
    scores = cross_val_score(lasso, X_train, y_train, cv=10, scoring='r2')
    mean_r2_scores_lasso.append(scores.mean())
    all_scores.append(scores)  # Conserver tous les scores

# Meilleure valeur de alpha pour Lasso
best_alpha_lasso = alpha_values[np.argmax(mean_r2_scores_lasso)]
best_r2_lasso = max(mean_r2_scores_lasso)

# Créer un DataFrame pour afficher les résultats détaillés de la validation croisée
cv_results = pd.DataFrame(all_scores, columns=[f'Fold {i+1}' for i in range(10)], index=alpha_values)
cv_results['Mean R²'] = mean_r2_scores_lasso

# Tracer les performances en fonction de alpha
plt.figure(figsize=(10, 6))
plt.plot(alpha_values, mean_r2_scores_lasso, marker='o', linestyle='-', color='blue', label='R² moyen (Lasso)')
plt.xscale('log')
plt.xlabel("Valeur de alpha")
plt.ylabel("R² moyen")
plt.title("Performances en fonction de alpha (Lasso)")
plt.axvline(best_alpha_lasso, color='r', linestyle='--', label=f'Alpha optimal: {best_alpha_lasso:.3f}')
plt.legend()
plt.show()

# Afficher les meilleurs paramètres et le meilleur score
print(f"Meilleure valeur de alpha (Lasso) : {best_alpha_lasso}")
print(f"Meilleur score R² (Lasso) : {best_r2_lasso}")
# Out:
# Meilleure valeur de alpha (Lasso) : 0.001
# Meilleur score R² (Lasso) : 0.4570141400554696

# %% [markdown]
# ### On obtient comme valeur un alpha égal à 0.001 et un score de 0.457 beaucoup plus meilleure que la première

# %% [markdown]
# ## Generer des features de la régression Lasso

# %%
# Entraîner un modèle Lasso avec le meilleur alpha
lasso_best = Lasso(alpha=best_alpha_lasso, max_iter=10000)
lasso_best.fit(X_train, y_train)

# Extraire les coefficients du modèle
lasso_coef = pd.Series(lasso_best.coef_, index=X_train.columns) 
lasso_coef_sorted = lasso_coef.abs().sort_values(ascending=False)

# Afficher les coefficients triés par importance
print("\nCoefficients triés par importance :")
print(lasso_coef_sorted.head())
# Out:
# Coefficients triés par importance :
# length          0.408669
# margin_up       0.268734
# height_right    0.253418
# height_left     0.167836
# diagonal        0.076893
# dtype: float64

# %%
# Affichage des résultats de la recherche croisée pour Ridge
cv_results_lasso = pd.DataFrame(grid_search_lasso.cv_results_)
cv_results_lasso.head(10)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.006401      0.004803         0.006397        0.003199
# 1       0.007998      0.000006         0.001599        0.003199
# 2       0.004797      0.003917         0.002400        0.003666
# 3       0.004799      0.003919         0.002400        0.003666
# 4       0.003998      0.003998         0.003202        0.003921
# 5       0.001600      0.003201         0.003198        0.003916
# 6       0.004000      0.004000         0.001600        0.003200
# 7       0.002402      0.003668         0.000000        0.000000
# 8       0.005600      0.003666         0.000000        0.000000
# 9       0.003202      0.003921         0.002398        0.003663
#
#   param_regressor__alpha param_regressor__fit_intercept  \
# 0                  0.001                           True
# 1                  0.001                          False
# 2                   0.01                           True
# ...

# %% [markdown]
# ## Importance des variables

# %%
# Prédictions sur l'ensemble de test
y_pred_lasso = lasso_best.predict(X_test)

# Afficher les premières prédictions
print("Prédictions pour Lasso sur X_test :")
print(y_pred_lasso)  # Af
# Out:
# Prédictions pour Lasso sur X_test :
# [4.96770859 4.29530486 4.37295994 4.09023983 4.00781969 4.1000914
#  4.85933889 4.1274291  4.18856039 3.85247758 5.14920391 4.12859526
#  4.44942366 4.08552407 5.91310676 4.10162109 4.12435115 3.96725587
#  4.17078283 5.09596937 4.23553199 4.78478548 5.01779904 4.09818938
#  4.07329475 4.00499924 4.16763609 4.09867162 4.92795699 4.24559641
#  5.10067826 4.15133021 4.49862694 4.18820942 3.9928443  4.18452947
#  3.9863584  5.59506442 5.71242001 4.151283   4.2519453  4.3932779
#  4.78552338 4.46953437 5.36199852 4.42564029 4.74121964 4.94344921
#  4.26720102 4.72794237 4.27563129 4.20546996 3.94196134 4.11057885
#  4.3364548  4.2083649  4.14303146 4.3819418  4.16989328 5.37075887
#  3.82647887 4.99243576 4.05259582 4.29972828 4.55993083 4.2610977
#  3.90451318 5.26805231 5.23760184 3.98094334 4.92138049 4.37391806
#  5.09330573 4.25296514 4.01947605 4.58876816 4.07093573 4.03450776
# ...

# %% [markdown]
# ## top30 most important features

# %%
# Extraire les coefficients du modèle Lasso
lasso_coef = pd.Series(lasso_best.coef_, index=X_train.columns)

# Créer un DataFrame pour afficher les coefficients
df_feature_importance_lasso = pd.DataFrame({
    'coef': lasso_coef
})

# Trier les coefficients par leur valeur absolue et obtenir les 30 premiers
top_30_features_lasso = df_feature_importance_lasso.sort_values("coef", key=lambda v: abs(v), ascending=True).head(30)

# Tracer un graphique des 30 features les plus importantes
top_30_features_lasso.plot(kind="barh", figsize=(10, 7))

# Ajouter un titre et une ligne verticale à zéro pour la référence
plt.title("Top 30 Features les plus importantes (Lasso)", fontsize=14)
plt.axvline(x=0, color='.6', linestyle="--")

# Ajuster l'espace autour du graphique pour le rendre plus lisible
plt.subplots_adjust(left=0.3)

# Afficher le graphique

# %% [markdown]
# ## Analyse des résultats

# %%
import matplotlib.pyplot as plt

# Visualisation des coefficients triés par importance pour Lasso
plt.figure(figsize=(10, 6))

# On suppose que `lasso_coef_sorted` est une Series contenant les coefficients triés par importance
lasso_coef_sorted.plot(kind='bar')

# Ajouter un titre et des labels
plt.title('Feature Importance - Lasso', fontsize=14)
plt.xlabel('Features', fontsize=12)
plt.ylabel('Absolute Coefficient Value', fontsize=12)

# Afficher le graphique
plt.show()

# %% [markdown]
# # Interprétation des Coefficients et Résultats du Modèle Lasso
#
# ## Coefficients du Modèle Lasso
#
# Le modèle Lasso présente des coefficients qui indiquent l'importance relative de chaque variable dans la prédiction. Les coefficients sont les suivants, triés par importance décroissante :
#
# | Variable        | Coefficient |
# |-----------------|------------|
# | length          | 0.408669    |
# | margin_up       | 0.268734    |
# | height_right    | 0.253418    |
# | height_left     | 0.167836    |
# | diagonal        | 0.076893    |
#
# ### Interprétation des Coefficients
#
# 1. **length** a le coefficient le plus élevé (0.408669), indiquant qu'elle a la plus grande influence sur la variable cible. Une variation dans `length` aura donc un impact plus significatif sur la prédiction par rapport aux autres variables.
#
# 2. **margin_up** et **height_right** suivent avec des coefficients respectifs de 0.268734 et 0.253418, ce qui montre qu'elles ont également un impact notable sur les prédictions, mais légèrement inférieur à celui de `length`.
#
# 3. **height_left** a un coefficient de 0.167836, ce qui indique que son influence est plus modeste, mais significative en comparaison avec `diagonal`.
#
# 4. **diagonal** a le coefficient le plus faible (0.076893), ce qui suggère que cette variable est la moins importante dans la prédiction parmi les variables considérées.
#
# ## Meilleure Valeur de \(\alpha\) et Meilleur Score \(R^2\) pour Lasso
#
# - **Meilleure valeur de \(\alpha\) pour Lasso :** 0.001
# - **Meilleur score \(R^2\) pour Lasso :** 0.4570141400554696
# - **Score \(R^2\) final pour Lasso :** 0.45690245395543594
#
# ### Interprétation
#
# La meilleure valeur de \(\alpha\) pour le modèle Lasso est 0.001, ce qui indique une régularisation faible. Le Lasso est une méthode de régularisation qui effectue également une sélection de variables en réduisant certains coefficients à zéro. Cependant, cette valeur de \(\alpha\) laisse encore un certain degré de flexibilité au modèle pour ajuster les coefficients sans trop pénaliser leur taille.
#
# Le score \(R^2\) de 0.457 indique que le modèle Lasso explique environ 45.7\% de la variance des données, une performance similaire à celle du modèle Ridge (0.4574). Le score final \(R^2\) de 0.4569 montre que le modèle Lasso est tout aussi performant, mais avec une légère différence, ce qui peut être attribué à la régularisation qui favorise la simplicité du modèle.
#
# ## Conclusion
#
# Dans le modèle Lasso, les variables `length`, `margin_up`, et `height_right` sont les plus influentes pour la prédiction de la variable cible, tandis que `diagonal` reste la moins importante. Le score \(R^2\) montre une performance similaire à celle du modèle Ridge, bien que le Lasso impose une régularisation plus forte. Cela signifie que le modèle Lasso peut être une bonne alternative pour la sélection de variables, mais la performance reste comparable à celle de Ridge pour cette tâche particulière.

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div style="border-radius: 10px; border: 2px solid #FFD700; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.1); text-align: left;">
#         <h3 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); font-size: 24px; font-weight: bold; margin-bottom: 10px;">
#             <span style="color: red ;"> 1.3</span>  Elastic Net
#         </h3>
#         <p style="font-size: 18px; color: #333;"></p>
# </html>

# %% [markdown]
# ## 1.3.1 Optimisation de la régression Elastic Net avec un pipeline et GridSearchCV

# %%
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
import pandas as pd

# Créer le pipeline Elastic Net
reg_elastic_pipe = Pipeline(steps=[
    ("scaler", MinMaxScaler()),
    ("regressor", ElasticNet())
])

# Définir la grille des hyperparamètres pour Elastic Net
param_grid_elastic = {
    "regressor__alpha": [0.001, 0.01, 0.1, 1, 10, 100],
    "regressor__l1_ratio": [0.1, 0.3, 0.5, 0.7, 0.9, 1],
    "regressor__fit_intercept": [True, False]
}

# Créer l'objet GridSearchCV pour Elastic Net
grid_search_elastic = GridSearchCV(reg_elastic_pipe, param_grid_elastic, cv=10, scoring="r2", return_train_score=True)

# Effectuer la recherche sur la grille pour Elastic Net
grid_search_elastic.fit(X_train, y_train)

# Afficher les meilleurs paramètres et le meilleur score pour Elastic Net
print("Meilleurs paramètres pour Elastic Net:", grid_search_elastic.best_params_)
print("Meilleur score R2 pour Elastic Net:", grid_search_elastic.best_score_)
# Out:
# Meilleurs paramètres pour Elastic Net: {'regressor__alpha': 0.001, 'regressor__fit_intercept': True, 'regressor__l1_ratio': 0.1}
# Meilleur score R2 pour Elastic Net: 0.45725272839341463

# %% [markdown]
# ### On trouve la valeur de alpha égale à 0.001 ou le l1_ratio égale à 0.1 et un score égale à 0.45725.

# %% [markdown]
# ## On optimise les paramètres alpha et l1_ratio simultanement pour trouver les valeurs optimales

# %%
from sklearn.linear_model import ElasticNet

# Définir une grille de valeurs pour alpha et l1_ratio
param_grid_elasticnet = {
    'alpha': np.logspace(-3, 3, 50),
    'l1_ratio': np.linspace(0.1, 0.9, 9)  # valeurs de l1_ratio entre 0.1 et 0.9
}

# Initialiser le modèle Elastic Net et GridSearchCV
elastic_net = ElasticNet(max_iter=10000)
grid_search_elasticnet = GridSearchCV(elastic_net, param_grid=param_grid_elasticnet, scoring='r2', cv=5)

# Entraîner le modèle
grid_search_elasticnet.fit(X_train, y_train)

# Obtenir les meilleures valeurs de alpha et l1_ratio, et le score associé
best_alpha_elasticnet = grid_search_elasticnet.best_params_['alpha']
best_l1_ratio_elasticnet = grid_search_elasticnet.best_params_['l1_ratio']
best_r2_elasticnet = grid_search_elasticnet.best_score_

print(f"Meilleure valeur de alpha (Elastic Net) : {best_alpha_elasticnet}")
print(f"Meilleure valeur de l1_ratio (Elastic Net) : {best_l1_ratio_elasticnet}")
print(f"Meilleur score R² (Elastic Net) : {best_r2_elasticnet}")
# Out:
# Meilleure valeur de alpha (Elastic Net) : 0.004094915062380427
# Meilleure valeur de l1_ratio (Elastic Net) : 0.1
# Meilleur score R² (Elastic Net) : 0.460029765667032

# %% [markdown]
# ### On obtient ainsi une valeur de alpha égale à 0.00409, celle de l1_ratio (Elastic Net) : 0.1 et enfin Meilleur score R² (Elastic Net) : 0.460029765667032

# %% [markdown]
# ## 1.3.2 Optimisation de la régression Elastic Net avec validation croisée (cross-validation)

# %%
from sklearn.linear_model import ElasticNet

# Range de valeurs pour alpha et l1_ratio
alpha_values = np.logspace(-3, 3, 50)
l1_ratio = 0.5  
mean_r2_scores_elasticnet = []

# Calcul du score R² moyen pour chaque valeur de alpha pour Elastic Net
for alpha in alpha_values:
    elastic_net = ElasticNet(alpha=alpha, l1_ratio=l1_ratio, max_iter=10000)
    scores = cross_val_score(elastic_net, X_train, y_train, cv=5, scoring='r2')
    mean_r2_scores_elasticnet.append(scores.mean())

# Meilleure valeur de alpha pour Elastic Net
best_alpha_elasticnet = alpha_values[np.argmax(mean_r2_scores_elasticnet)]
best_r2_elasticnet = max(mean_r2_scores_elasticnet)

# Tracer les résultats pour Elastic Net
plt.figure(figsize=(10, 6))
plt.plot(alpha_values, mean_r2_scores_elasticnet, marker='o', linestyle='-', color='b', label='R² moyen (Elastic Net)')
plt.xscale('log')
plt.xlabel("Valeur de alpha")
plt.ylabel("R² moyen")
plt.title("Performances en fonction de alpha (Elastic Net)")
plt.axvline(best_alpha_elasticnet, color='r', linestyle='--', label=f'Alpha optimal: {best_alpha_elasticnet:.3f}')
plt.legend()
plt.show()

print(f"Meilleure valeur de alpha (Elastic Net) : {best_alpha_elasticnet}")
print(f"Meilleur score R² (Elastic Net) : {best_r2_elasticnet}")
# Out:
# Meilleure valeur de alpha (Elastic Net) : 0.001
# Meilleur score R² (Elastic Net) : 0.45335417182452653

# %% [markdown]
# ### On obtient ainsi une valeur comprise de alpha égale à 0.001 en maintenant l1_ratio à 0.1 et un R2 égale à 0.45335417 similaire au précédent.

# %% [markdown]
# ## Generer des features pour la regression Elastic Net

# %%
# Générer la feature importance pour Elastic net
df_feature_importance = pd.DataFrame(grid_search_elastic.best_estimator_[-1].coef_, columns=["coef"], index=grid_search_elastic.feature_names_in_)
print(f"Shape: {df_feature_importance.shape}")
df_feature_importance.head()
# Out:
# Shape: (5, 1)
#                   coef
# diagonal     -0.156502
# height_left   0.296283
# height_right  0.526133
# margin_up     0.403018
# length       -1.715256

# %%
cv_results_df = pd.DataFrame(grid_search_elastic.cv_results_)
cv_results_df
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.006095      0.002211         0.002900        0.001300
# 1        0.003498      0.000922         0.001699        0.000458
# 2        0.003097      0.000700         0.001501        0.000499
# 3        0.003098      0.000305         0.001401        0.000492
# 4        0.002999      0.000007         0.001399        0.000490
# ..            ...           ...              ...             ...
# 67       0.003296      0.000641         0.001597        0.000488
# 68       0.002898      0.000304         0.001601        0.000488
# 69       0.002898      0.000535         0.001599        0.000490
# 70       0.003199      0.000400         0.001697        0.000639
# 71       0.002897      0.000304         0.001499        0.000497
#
#    param_regressor__alpha param_regressor__fit_intercept  \
# 0                   0.001                           True
# 1                   0.001                           True
# ...

# %% [markdown]
# ## Importance des variables

# %%
grid_search_elastic.predict(X_test)
# Out:
# array([4.96149092, 4.31397681, 4.37478374, 4.09006689, 4.02001783,
#        4.0999894 , 4.85338943, 4.12918241, 4.20163813, 3.84385615,
#        5.14144784, 4.1507023 , 4.44757826, 4.083338  , 5.89275757,
#        4.10995074, 4.14599108, 3.96052968, 4.16552597, 5.10275207,
#        4.2322817 , 4.7881353 , 5.00012311, 4.10923921, 4.07179721,
#        4.00041254, 4.18064844, 4.09933278, 4.91327718, 4.23878664,
#        5.08853498, 4.15223963, 4.50091215, 4.19451234, 3.98677442,
#        4.19058279, 3.98514758, 5.58078776, 5.69500731, 4.15417643,
#        4.27078962, 4.40475158, 4.78570379, 4.47170709, 5.3438884 ,
#        4.41863333, 4.73714358, 4.93716726, 4.26288096, 4.72074935,
#        4.28441841, 4.21740769, 3.93407053, 4.11401841, 4.33859904,
#        4.20371351, 4.16192982, 4.37995993, 4.16581396, 5.36191285,
#        3.84511086, 4.97260538, 4.04987153, 4.30251461, 4.5757394 ,
#        4.25720035, 3.90822688, 5.25064062, 5.22289604, 3.98435382,
# ...

# %% [markdown]
# ## top30 most important features

# %%
# Récupérer les meilleurs paramètres du modèle Elastic Net
best_params = grid_search_elastic.best_params_

# Recréer le modèle ElasticNet avec les meilleurs paramètres
best_elastic_model = ElasticNet(
    alpha=best_params["regressor__alpha"],
    l1_ratio=best_params["regressor__l1_ratio"],
    fit_intercept=best_params["regressor__fit_intercept"]
)

# Entraîner le modèle sur l’ensemble d’entraînement complet
best_elastic_model.fit(X_train, y_train)

# Créer un DataFrame pour les coefficients des features
feature_importance = pd.DataFrame({
    'feature': X_train.columns,
    'coef': best_elastic_model.coef_
})

# Trier les features par importance (valeur absolue des coefficients) et sélectionner les 30 plus importantes
top_features = (feature_importance
                .reindex(feature_importance['coef'].abs().sort_values(ascending=False).index)
                .head(30))

# Afficher les 30 features les plus importantes
plt.figure(figsize=(10, 8))
plt.barh(top_features['feature'], top_features['coef'], color='blue')
plt.xlabel("Coefficient")
plt.ylabel("Feature")
plt.title("Top 30 Most Important Features - Elastic Net")
plt.gca().invert_yaxis()  # Inverser pour avoir les plus importantes en haut
plt.show()

# %% [markdown]
# ### Analyse des résultats

# %%
# Extraire les coefficients du modèle Elastic Net ajusté avec les meilleurs paramètres
elastic_net_best_model = grid_search_elastic.best_estimator_.named_steps['regressor']
elastic_net_coef = elastic_net_best_model.coef_

# Créer un DataFrame pour stocker les coefficients avec leurs noms de features
coef_df = pd.DataFrame({
    "Feature": X_train.columns,
    "Coefficient": elastic_net_coef
})

# Trier les coefficients par valeur absolue pour les 30 features les plus importantes
coef_df['Abs_Coefficient'] = np.abs(coef_df['Coefficient'])
coef_df = coef_df.sort_values("Abs_Coefficient", ascending=False).head(30)

# Visualisation des 30 features les plus importantes
plt.figure(figsize=(12, 8))
coef_df.plot(kind="barh", x="Feature", y="Abs_Coefficient", color="blue", legend=False)
plt.title(' Feature Importance - Elastic Net', fontsize=16)
plt.xlabel('Absolute Coefficient Value', fontsize=14)
plt.ylabel('Features', fontsize=14)
plt.gca().invert_yaxis()  
plt.tight_layout()
plt.show()

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div style="border-radius: 10px; border: 2px solid #FFD700; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.1); text-align: left;">
#         <h3 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); font-size: 24px; font-weight: bold; margin-bottom: 10px;">
#             <span style="color: red ;"></span>
# Interprétation des Coefficients et Résultats du Modèle Elastic Net
#         </h3>
#         <p style="font-size: 18px; color: #333;">
# </html>

# %% [markdown]
# # Interprétation des Coefficients et Résultats du Modèle Elastic Net
#
# ## Coefficients du Modèle Elastic Net
#
# Le modèle Elastic Net présente les coefficients suivants, triés par importance :
#
# | Variable        | Coefficient |
# |-----------------|------------|
# | diagonal        | -0.156502   |
# | height_left     | 0.296283    |
# | height_right    | 0.526133    |
# | margin_up       | 0.403018    |
# | length          | -1.715256   |
#
# ### Interprétation des Coefficients
#
# 1. **length** a le coefficient le plus bas (-1.715256), ce qui indique que cette variable a un effet négatif important sur la variable cible. Cela suggère que lorsqu'elle augmente, la variable cible diminue fortement.
#
# 2. **height_right** a le coefficient le plus élevé (0.526133), ce qui montre qu'elle exerce la plus grande influence positive sur la prédiction de la variable cible. Une augmentation de `height_right` aura un impact substantiel pour augmenter la variable cible.
#
# 3. **margin_up** suit avec un coefficient de 0.403018, indiquant qu'elle a également un effet positif notable, mais un peu moins important que `height_right`.
#
# 4. **height_left** a un coefficient de 0.296283, ce qui montre qu'elle a un effet positif, bien que plus modéré par rapport à `height_right` et `margin_up`.
#
# 5. **diagonal**, avec un coefficient de -0.156502, montre un effet négatif plus faible, indiquant que son influence sur la variable cible est relativement modeste et opposée à celle des autres variables.
#
# ## Meilleure Valeur de \(\alpha\) et Meilleur Score \(R^2\) pour Elastic Net
#
# - **Meilleure valeur de \(\alpha\) pour Elastic Net :** 0.001
# - **Meilleur score \(R^2\) pour Elastic Net :** 0.45335417182452653
#
# ### Interprétation
#
# La meilleure valeur de \(\alpha\) pour le modèle Elastic Net est 0.001, ce qui montre une régularisation faible. Elastic Net combine les avantages du Lasso et du Ridge en permettant à la fois une régularisation et une sélection de variables. La petite valeur de \(\alpha\) indique que la régularisation est relativement faible, ce qui permet au modèle de capturer plus de variations dans les données tout en régularisant légèrement les coefficients.
#
# Le score \(R^2\) de 0.453 indique que le modèle Elastic Net explique environ 45.3\% de la variance des données, ce qui est légèrement inférieur aux performances des modèles Ridge et Lasso. Cependant, il reste un bon compromis entre la performance et la capacité à effe## Conclusionction de variables.
#
# ## Conclusion
#
# Le modèle Elastic Net présente des coefficients intéressants, où les variables `length`, `height_right`, et `margin_up` ont une influence significative sur la variable cible, tandis que `diagonal` a une influence relativement faible. Bien que le score \(R^2\) pour Elastic Net soit légèrement plus bas que celui de Ridge et Lasso, le modèle reste compétitif et offre une bonne capacité de régularisation et de sélection de variables. La régularisation modérée à faible de \(\alpha = 0.001\) permet de bien ajuster les coefficients tout en limitant le surapprentissage.

# %% [markdown]
# ## Autres Methode: Avec de meilleure performance

# %%
class RegressionAnalyzer:
    def __init__(self, random_state: int = 42):
        """
        Initialize the regression analyzer with multiple models.
        
        Args:
            random_state (int): Random seed for reproducibility
        """
        self.random_state = random_state
        self.models = {
            'Ridge': Ridge(alpha=1.0),
            'Lasso': Lasso(alpha=0.1),
            'ElasticNet': ElasticNet(alpha=0.1, l1_ratio=0.5)
        }
        self.scaler = StandardScaler()
        self.results = {}

    def prepare_data(self, X: pd.DataFrame, y: pd.Series) -> Tuple[np.ndarray, np.ndarray, np.ndarray, np.ndarray]:
        """
        Prepare and split the data for modeling.
        
        Args:
            X (pd.DataFrame): Feature matrix
            y (pd.Series): Target variable
            
        Returns:
            Tuple containing training and test sets
        """
        X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=0.3, random_state=self.random_state
        )
        
        # Scale features
        X_train_scaled = self.scaler.fit_transform(X_train)
        X_test_scaled = self.scaler.transform(X_test)
        
        return X_train_scaled, X_test_scaled, y_train, y_test

    def train_and_evaluate(self, X_train: np.ndarray, X_test: np.ndarray, 
                          y_train: np.ndarray, y_test: np.ndarray) -> Dict:
        """
        Train models and compute predictions and metrics.
        
        Args:
            X_train, X_test, y_train, y_test: Training and test datasets
            
        Returns:
            Dictionary containing results for each model
        """
        for name, model in self.models.items():
            # Train model
            model.fit(X_train, y_train)
            
            # Make predictions
            y_pred_train = model.predict(X_train)
            y_pred_test = model.predict(X_test)
            
            # Compute metrics
            metrics = {
                'train': {
                    'mse': mean_squared_error(y_train, y_pred_train),
                    'rmse': np.sqrt(mean_squared_error(y_train, y_pred_train)),
                    'mae': mean_absolute_error(y_train, y_pred_train),
                    'r2': r2_score(y_train, y_pred_train)
                },
                'test': {
                    'mse': mean_squared_error(y_test, y_pred_test),
                    'rmse': np.sqrt(mean_squared_error(y_test, y_pred_test)),
                    'mae': mean_absolute_error(y_test, y_pred_test),
                    'r2': r2_score(y_test, y_pred_test)
                },
                'predictions': {
                    'train': {'actual': y_train, 'predicted': y_pred_train},
                    'test': {'actual': y_test, 'predicted': y_pred_test}
                }
            }
            
            # Add cross-validation scores
            cv_scores = cross_val_score(model, X_train, y_train, cv=5, scoring='r2')
            metrics['cv_r2_mean'] = cv_scores.mean()
            metrics['cv_r2_std'] = cv_scores.std()
            
            self.results[name] = metrics

        return self.results

    def plot_predictions(self, title_fontsize: int = 12, figsize: Tuple[int, int] = (15, 5)):
        """
        Create enhanced scatter plots of predicted vs actual values.
        """
        for name, results in self.results.items():
            fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
            fig.suptitle(f'{name} Regression - Predictions vs Actual Values', 
                        fontsize=title_fontsize+2)
            
            # Training set
            self._plot_prediction_subplot(
                ax1, results['predictions']['train'],
                'Training Set', 'blue', name
            )
            
            # Test set
            self._plot_prediction_subplot(
                ax2, results['predictions']['test'],
                'Test Set', 'red', name
            )
            
            plt.tight_layout()
            plt.show()

    def _plot_prediction_subplot(self, ax, data: Dict, title: str, color: str, model_name: str):
        """Helper function for plotting prediction subplots."""
        actual, predicted = data['actual'], data['predicted']
        
        # Create scatter plot
        ax.scatter(actual, predicted, alpha=0.5, color=color, label='Predictions')
        
        # Add perfect prediction line
        min_val = min(actual.min(), predicted.min())
        max_val = max(actual.max(), predicted.max())
        ax.plot([min_val, max_val], [min_val, max_val], 'k--', 
                label='Perfect Predictions', alpha=0.8)
        
        # Add regression line
        z = np.polyfit(actual, predicted, 1)
        p = np.poly1d(z)
        ax.plot(actual, p(actual), color='green', alpha=0.8, 
                label=f'Trend Line (slope={z[0]:.2f})')
        
        # Customize plot
        ax.set_xlabel('Actual Values')
        ax.set_ylabel('Predicted Values')
        ax.set_title(f'{model_name} - {title}\n$R^2 = {r2_score(actual, predicted):.3f}$')
        ax.legend()
        ax.grid(True, alpha=0.3)

    def plot_residuals(self, figsize: Tuple[int, int] = (15, 5)):
        """
        Create enhanced residual plots with both boxplots and distributions.
        """
        for name, results in self.results.items():
            fig, (ax1, ax2) = plt.subplots(1, 2, figsize=figsize)
            fig.suptitle(f'{name} Regression - Residual Analysis', fontsize=14)
            
            # Calculate residuals
            train_residuals = (results['predictions']['train']['actual'] - 
                             results['predictions']['train']['predicted'])
            test_residuals = (results['predictions']['test']['actual'] - 
                            results['predictions']['test']['predicted'])
            
            # Boxplot
            sns.boxplot(data=[train_residuals, test_residuals], 
                       ax=ax1, palette=['blue', 'red'])
            ax1.set_xticklabels(['Training', 'Test'])
            ax1.set_title('Residuals Distribution')
            ax1.set_ylabel('Residual Value')
            
            # Distribution plot
            sns.kdeplot(data=train_residuals, ax=ax2, color='blue', 
                       label='Training', fill=True, alpha=0.3)
            sns.kdeplot(data=test_residuals, ax=ax2, color='red', 
                       label='Test', fill=True, alpha=0.3)
            ax2.set_title('Residuals Density Distribution')
            ax2.set_xlabel('Residual Value')
            ax2.legend()
            
            plt.tight_layout()
            plt.show()

    def print_metrics(self):
        """
        Print comprehensive metrics for all models.
        """
        print("\n=== Model Performance Metrics ===")
        metrics_df = []
        
        for name, results in self.results.items():
            metrics = {
                'Model': name,
                'Train R²': results['train']['r2'],
                'Test R²': results['test']['r2'],
                'CV R² (mean)': results['cv_r2_mean'],
                'CV R² (std)': results['cv_r2_std'],
                'Train RMSE': results['train']['rmse'],
                'Test RMSE': results['test']['rmse'],
                'Train MAE': results['train']['mae'],
                'Test MAE': results['test']['mae']
                
            }
            metrics_df.append(metrics)
        
        df = pd.DataFrame(metrics_df).round(3)
        print(df.to_string(index=False))
        
        
        best_model = df.loc[df['Test R²'].idxmax()]
        print(f"\nBest performing model: {best_model['Model']}")
        print(f"Test R² score: {best_model['Test R²']:.3f}")

def main(data: pd.DataFrame, target_col: str):
    """
    Main function to run the complete analysis.
    
    Args:
        data (pd.DataFrame): Input DataFrame
        target_col (str): Name of target column
    """
    
    data_cleaned = data.dropna(subset=[target_col])
    
    
    X = data_cleaned.drop(columns=[target_col])
    y = data_cleaned[target_col]
    
    
    analyzer = RegressionAnalyzer()
    X_train, X_test, y_train, y_test = analyzer.prepare_data(X, y)
    analyzer.train_and_evaluate(X_train, X_test, y_train, y_test)
    
   
    analyzer.plot_predictions()
    analyzer.plot_residuals()
    analyzer.print_metrics()
    
    return analyzer

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div style="border-radius: 10px; border: 2px solid #FFD700; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.1); text-align: left;">
#         <h3 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); font-size: 24px; font-weight: bold; margin-bottom: 10px;">
#             <span style="color: red ;"></span>  Résultats
#         </h3>
#         <p style="font-size: 18px; color: #333;"></p>
# </html>

# %%
analyzer = main(data, 'margin_low')
# Out:
# === Model Performance Metrics ===
#      Model  Train R²  Test R²  CV R² (mean)  CV R² (std)  Train RMSE  Test RMSE  Train MAE  Test MAE
#      Ridge     0.607    0.640         0.598        0.020       0.419      0.392      0.320     0.307
#      Lasso     0.581    0.612         0.578        0.015       0.432      0.407      0.330     0.313
# ElasticNet     0.592    0.622         0.587        0.019       0.427      0.402      0.327     0.310
#
# Best performing model: Ridge
# Test R² score: 0.640

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title></title>
# </head>
# <body>
#     <div style="border-radius: 10px; border: 2px solid #FFD700; padding: 20px; background-color: #E8F6EF; box-shadow: 0px 6px 12px rgba(0, 0, 0, 0.1); text-align: left;">
#         <h3 style="color: #17A05D; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); font-size: 24px; font-weight: bold; margin-bottom: 10px;">
#             <span style="color: red ;"></span>  Conclusion  Finale
#         </h3>
#         <p style="font-size: 18px; color: #333;"></p>
# </html>

# %% [markdown]
# # Interprétation Globale
#
# ## Comparaison des Modèles
#
# Les trois modèles (Ridge, Lasso et Elastic Net) ont montré des performances similaires en termes de score \(R^2\), mais chaque modèle a des caractéristiques distinctes en fonction de la régularisation et de la sélection des variables.
#
# ### Ridge
#
# - **Meilleure valeur de \(\alpha\) :** 8.29
# - **Meilleur score \(R^2\) :** 0.4574
# - **Coefficients :** Les variables `length`, `margin_up`, et `height_right` ont les plus grands coefficients, indiquant leur influence significative sur la variable cible. Ridge est particulièrement efficace lorsque toutes les variables sont importantes, car il applique une régularisation sans exclure aucune variable.
#
# ### Lasso
#
# - **Meilleure valeur de \(\alpha\) :** 0.001
# - **Meilleur score \(R^2\) :** 0.4570
# - **Coefficients :** Lasso a tendance à réduire certains coefficients à zéro, ce qui en fait un bon choix pour la sélection de variables. Les variables `length`, `margin_up`, et `height_right` sont également importantes, mais certaines variables moins significatives (comme `diagonal`) peuvent être exclues du modèle. Lasso offre ainsi une régularisation plus forte et une meilleure simplification du modèle en éliminant certaines variables.
#
# ### Elastic Net
#
# - **Meilleure valeur de \(\alpha\) :** 0.001
# - **Meilleur score \(R^2\) :** 0.4534
# - **Coefficients :** Elastic Net combine les avantages de Ridge et Lasso, en appliquant une régularisation moins forte que Lasso tout en permettant une sélection de variables. Les variables `length`, `height_right`, et `margin_up` sont fortement influentes, tandis que `diagonal` a un coefficient plus faible, indiquant qu'elle a une moindre importance. Elastic Net peut être particulièrement utile lorsque vous souhaitez une combinaison de régularisation et de sélection de variables, tout en conservant un modèle flexible.
#
# ## Conclusion
#
# ### Le Modèle le Plus Efficace
#
# Tous les modèles ont un score \(R^2\) très proche, mais **le modèle Ridge** se distingue légèrement par sa capacité à maintenir la contribution de toutes les variables tout en fournissant un score \(R^2\) légèrement plus élevé (0.4574). Ridge est le plus efficace lorsqu'il n'est pas nécessaire d'effectuer une sélection stricte des variables, car il permet à chaque variable de contribuer sans réduire leur importance à zéro.
#
# Cependant, **Lasso** reste une excellente option si l'objectif est de réaliser une sélection de variables et de simplifier le modèle en éliminant celles qui ont une influence faible ou négligeable. Bien que Lasso ait un score \(R^2\) légèrement inférieur, il peut offrir une meilleure interprétabilité en rendant certains coefficients nuls.
#
# **Elastic Net** représente un compromis entre Ridge et Lasso, offrant à la fois une régularisation et une sélection de variables, mais avec un score \(R^2\) légèrement plus faible. Elastic Net est particulièrement recommandé lorsque l'on cherche à combiner les avantages des deux précédents modèles, surtout dans des contextes où les variables sont fortement coPourndation
#
# - Si le but est d'obtenir la **meilleure performance globale** tout en gardant une complexité modéréeSi nous lettons mettreplus efficace.
# - Si l'accent est mis sur la **sélection de variables** et la simplicité du modèleAfin d'obtenir Lasso** pourrait être préféré.
# - Pour un **compromis équilibré** entre régularisation et sélection de variables, **Elastic Net** est un bon choix.
